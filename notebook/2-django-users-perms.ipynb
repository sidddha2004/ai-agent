# %%
import setup  # notebooks/setup.py
setup.init()

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

# list -> get 
User.objects.all()
# Out:
# <QuerySet [<User: sid>, <User: normal_user>]>

# %%
# help(User)

# %%
# user_obj = User.objects.create(
#    username="ethan_hunt"
# )

user_obj = User.objects.get(
    username="sid"
)
user_obj.is_staff = True # can login to Djanngo admin or not

# django form -> html form -> api request
user_obj.set_password("abc123007")

user_obj.save()
user_obj.is_staff
# Out:
# True

# %%
# user_obj.password
# Out:
# 'pbkdf2_sha256$1000000$w2tCB1eYyYyzndDbJInOpm$15h7ZYyJWBN+0FuRFiGvMm1eNboo+a5SzZd6UFr1mTo='

# %%
# detail -> get
user_obj = User.objects.last()
user_obj
# Out:
# <User: normal_user>

# %%
# create or update
# user_obj.save() # pre_save -> post_save

# %%
# delete
# user_obj.delete()

# %%
from documents.models import Document

doc_obj = Document(
    owner=user_obj,
    title="Hello world"
)
doc_obj
# Out:
# <Document: Hello world>

# %%
doc_obj.save()

# %%
doc_obj
# Out:
# <Document: Hello world>

# %%
Document.objects.create(owner=user_obj)
# Out:
# <Document: Title>

# %%
user_obj.id
# Out:
# 2

# %%
Document.objects.create(owner_id=2)
# Out:
# <Document: Title>
